# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os

# %%
def melspec_to_rgb_image(audio_dir, image_dir, img_width=224, img_height=224, dpi=100):
    """
    Converts an audio file to a dB-scaled mel spectrogram,
    Transforms it into an RGB 3D tensor, and saves it.
    Args:
        audio_dir (str): Parent directory of audio files
        image_dir (str): Parent directory to save the output RGB image
        img_width (int): Desired width of the output image in pixels
        img_height (int): Desired height of the output image in pixels
        dpi (int): Dots per inch for figure resolution
    """

    audio_files = os.listdir(audio_dir)

    if not os.path.exists(image_dir):
        os.makedirs(image_dir)
    
    for i in range(len(audio_files)):
        audio = audio_files[i]
        audio_path = os.path.join(audio_dir, audio)
        image_path = os.path.join(image_dir, audio.replace(".mp3", ".png"))
        # Loading the audio file
        y, sr = librosa.load(audio_path, sr=None)
    
        # Computing the mel spectrogram
        mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr)
    
        # Converting to decibels (dB) scale
        mel_spectrogram_db = librosa.power_to_db(mel_spectrogram, ref=np.max)
    
        # Plotting the spectrogram as an image without axes or borders
        # Adjusting figure size to match desired pixel dimensions at specified DPI
        fig = plt.figure(figsize=(img_width/dpi, img_height/dpi), dpi=dpi, frameon=False)
        ax = plt.Axes(fig, [0., 0., 1., 1.])
        ax.set_axis_off()
        fig.add_axes(ax)
        librosa.display.specshow(mel_spectrogram_db, sr=sr, ax=ax, cmap='viridis') # 'viridis' is a good colormap
        
        # Saving the plot to a file
        plt.savefig(image_path, bbox_inches='tight', pad_inches=0)
        plt.close(fig) # Close the figure to free memory
        if (i+1) == len(audio_files):
            print(f"Successfully created and saved ({len(audio_files)}) RGB images in {image_dir}")

# %%
parent_dir_audio = "data/splitted/phishing"
parent_dir_image = "data/input_features/image/phishing"
audio_dir_list = [os.path.join(parent_dir_audio, f) for f in os.listdir(parent_dir_audio) if not f.startswith('.')]
image_dir_list = [os.path.join(parent_dir_image, f) for f in os.listdir(parent_dir_audio) if not f.startswith('.')]

# %%
for i in range(len(audio_dir_list)):
    audio_dir = audio_dir_list[i]
    image_dir = image_dir_list[i]
    print(f"*********** Converting {i+1}/{len(audio_dir_list)} ***********")
    if audio_dir.rsplit('/', 1)[-1] == image_dir.rsplit('/', 1)[-1]:
        melspec_to_rgb_image(audio_dir, image_dir)
    else:
        print(f"Source file (audio) is different from destination file (image)")
# Out:
# *********** Converting 1/412 ***********
# Successfully created and saved (8) RGB images in data/input_features/image/phishing/data_agency_183
# *********** Converting 2/412 ***********
# Successfully created and saved (8) RGB images in data/input_features/image/phishing/data_agency_86
# *********** Converting 3/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_91
# *********** Converting 4/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_177
# *********** Converting 5/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_32
# *********** Converting 6/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_130
# *********** Converting 7/412 ***********
# Successfully created and saved (8) RGB images in data/input_features/image/phishing/data_loan_24
# *********** Converting 8/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_184
# *********** Converting 9/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_agency_15
# *********** Converting 10/412 ***********
# Successfully created and saved (18) RGB images in data/input_features/image/phishing/data_loan_54
# *********** Converting 11/412 ***********
# Successfully created and saved (8) RGB images in data/input_features/image/phishing/data_agency_121
# *********** Converting 12/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_35
# *********** Converting 13/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_104
# *********** Converting 14/412 ***********
# Successfully created and saved (26) RGB images in data/input_features/image/phishing/data_agency_194
# *********** Converting 15/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_51
# *********** Converting 16/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_61
# *********** Converting 17/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_182
# *********** Converting 18/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_157
# *********** Converting 19/412 ***********
# Successfully created and saved (14) RGB images in data/input_features/image/phishing/data_agency_134
# *********** Converting 20/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_199
# *********** Converting 21/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_156
# *********** Converting 22/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_56
# *********** Converting 23/412 ***********
# Successfully created and saved (8) RGB images in data/input_features/image/phishing/data_loan_76
# *********** Converting 24/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_agency_7
# *********** Converting 25/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_75
# *********** Converting 26/412 ***********
# Successfully created and saved (20) RGB images in data/input_features/image/phishing/data_agency_78
# *********** Converting 27/412 ***********
# Successfully created and saved (7) RGB images in data/input_features/image/phishing/data_agency_161
# *********** Converting 28/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_loan_60
# *********** Converting 29/412 ***********
# Successfully created and saved (15) RGB images in data/input_features/image/phishing/data_agency_118
# *********** Converting 30/412 ***********
# Successfully created and saved (7) RGB images in data/input_features/image/phishing/data_loan_50
# *********** Converting 31/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_22
# *********** Converting 32/412 ***********
# Successfully created and saved (13) RGB images in data/input_features/image/phishing/data_loan_163
# *********** Converting 33/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_176
# *********** Converting 34/412 ***********
# Successfully created and saved (7) RGB images in data/input_features/image/phishing/data_agency_156
# *********** Converting 35/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_227
# *********** Converting 36/412 ***********
# Successfully created and saved (9) RGB images in data/input_features/image/phishing/data_loan_84
# *********** Converting 37/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_26
# *********** Converting 38/412 ***********
# Successfully created and saved (52) RGB images in data/input_features/image/phishing/data_agency_135
# *********** Converting 39/412 ***********
# Successfully created and saved (14) RGB images in data/input_features/image/phishing/data_agency_68
# *********** Converting 40/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_28
# *********** Converting 41/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_180
# *********** Converting 42/412 ***********
# Successfully created and saved (12) RGB images in data/input_features/image/phishing/data_agency_168
# *********** Converting 43/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_74
# *********** Converting 44/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_loan_173
# *********** Converting 45/412 ***********
# Successfully created and saved (8) RGB images in data/input_features/image/phishing/data_agency_214
# *********** Converting 46/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_160
# *********** Converting 47/412 ***********
# Successfully created and saved (9) RGB images in data/input_features/image/phishing/data_loan_23
# *********** Converting 48/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_80
# *********** Converting 49/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_52
# *********** Converting 50/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_172
# *********** Converting 51/412 ***********
# Successfully created and saved (11) RGB images in data/input_features/image/phishing/data_agency_142
# *********** Converting 52/412 ***********
# Successfully created and saved (8) RGB images in data/input_features/image/phishing/data_loan_26
# *********** Converting 53/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_loan_131
# *********** Converting 54/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_28
# *********** Converting 55/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_125
# *********** Converting 56/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_3
# *********** Converting 57/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_178
# *********** Converting 58/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_36
# *********** Converting 59/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_agency_35
# *********** Converting 60/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_89
# *********** Converting 61/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_181
# *********** Converting 62/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_34
# *********** Converting 63/412 ***********
# Successfully created and saved (20) RGB images in data/input_features/image/phishing/data_agency_101
# *********** Converting 64/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_loan_149
# *********** Converting 65/412 ***********
# Successfully created and saved (11) RGB images in data/input_features/image/phishing/data_agency_126
# *********** Converting 66/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_43
# *********** Converting 67/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_184
# *********** Converting 68/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_agency_147
# *********** Converting 69/412 ***********
# Successfully created and saved (10) RGB images in data/input_features/image/phishing/data_agency_42
# *********** Converting 70/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_44
# *********** Converting 71/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_196
# *********** Converting 72/412 ***********
# Successfully created and saved (11) RGB images in data/input_features/image/phishing/data_agency_41
# *********** Converting 73/412 ***********
# Successfully created and saved (29) RGB images in data/input_features/image/phishing/data_agency_47
# *********** Converting 74/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_agency_50
# *********** Converting 75/412 ***********
# Successfully created and saved (8) RGB images in data/input_features/image/phishing/data_loan_61
# *********** Converting 76/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_163
# *********** Converting 77/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_81
# *********** Converting 78/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_1
# *********** Converting 79/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_116
# *********** Converting 80/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_185
# *********** Converting 81/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_agency_219
# *********** Converting 82/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_176
# *********** Converting 83/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_87
# *********** Converting 84/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_loan_57
# *********** Converting 85/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_45
# *********** Converting 86/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_21
# *********** Converting 87/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_38
# *********** Converting 88/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_151
# *********** Converting 89/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_85
# *********** Converting 90/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_94
# *********** Converting 91/412 ***********
# Successfully created and saved (18) RGB images in data/input_features/image/phishing/data_loan_10
# *********** Converting 92/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_agency_207
# *********** Converting 93/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_loan_150
# *********** Converting 94/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_loan_159
# *********** Converting 95/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_62
# *********** Converting 96/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_18
# *********** Converting 97/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_99
# *********** Converting 98/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_123
# *********** Converting 99/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_73
# *********** Converting 100/412 ***********
# Successfully created and saved (12) RGB images in data/input_features/image/phishing/data_loan_20
# *********** Converting 101/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_81
# *********** Converting 102/412 ***********
# Successfully created and saved (57) RGB images in data/input_features/image/phishing/data_agency_193
# *********** Converting 103/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_171
# *********** Converting 104/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_211
# *********** Converting 105/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_76
# *********** Converting 106/412 ***********
# Successfully created and saved (10) RGB images in data/input_features/image/phishing/data_agency_157
# *********** Converting 107/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_agency_123
# *********** Converting 108/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_48
# *********** Converting 109/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_108
# *********** Converting 110/412 ***********
# Successfully created and saved (7) RGB images in data/input_features/image/phishing/data_loan_119
# *********** Converting 111/412 ***********
# Successfully created and saved (15) RGB images in data/input_features/image/phishing/data_loan_145
# *********** Converting 112/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_agency_51
# *********** Converting 113/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_169
# *********** Converting 114/412 ***********
# Successfully created and saved (9) RGB images in data/input_features/image/phishing/data_loan_58
# *********** Converting 115/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_59
# *********** Converting 116/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_129
# *********** Converting 117/412 ***********
# Successfully created and saved (44) RGB images in data/input_features/image/phishing/data_agency_212
# *********** Converting 118/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_98
# *********** Converting 119/412 ***********
# Successfully created and saved (32) RGB images in data/input_features/image/phishing/data_agency_190
# *********** Converting 120/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_134
# *********** Converting 121/412 ***********
# Successfully created and saved (8) RGB images in data/input_features/image/phishing/data_agency_222
# *********** Converting 122/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_164
# *********** Converting 123/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_197
# *********** Converting 124/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_206
# *********** Converting 125/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_46
# *********** Converting 126/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_87
# *********** Converting 127/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_135
# *********** Converting 128/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_53
# *********** Converting 129/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_17
# *********** Converting 130/412 ***********
# Successfully created and saved (27) RGB images in data/input_features/image/phishing/data_agency_188
# *********** Converting 131/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_41
# *********** Converting 132/412 ***********
# Successfully created and saved (24) RGB images in data/input_features/image/phishing/data_agency_34
# *********** Converting 133/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_128
# *********** Converting 134/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_91
# *********** Converting 135/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_47
# *********** Converting 136/412 ***********
# Successfully created and saved (7) RGB images in data/input_features/image/phishing/data_loan_165
# *********** Converting 137/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_23
# *********** Converting 138/412 ***********
# Successfully created and saved (13) RGB images in data/input_features/image/phishing/data_agency_205
# *********** Converting 139/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_185
# *********** Converting 140/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_114
# *********** Converting 141/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_37
# *********** Converting 142/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_164
# *********** Converting 143/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_95
# *********** Converting 144/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_119
# *********** Converting 145/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_107
# *********** Converting 146/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_8
# *********** Converting 147/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_5
# *********** Converting 148/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_153
# *********** Converting 149/412 ***********
# Successfully created and saved (10) RGB images in data/input_features/image/phishing/data_loan_141
# *********** Converting 150/412 ***********
# Successfully created and saved (7) RGB images in data/input_features/image/phishing/data_agency_66
# *********** Converting 151/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_48
# *********** Converting 152/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_45
# *********** Converting 153/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_86
# *********** Converting 154/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_7
# *********** Converting 155/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_139
# *********** Converting 156/412 ***********
# Successfully created and saved (35) RGB images in data/input_features/image/phishing/data_agency_131
# *********** Converting 157/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_5
# *********** Converting 158/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_66
# *********** Converting 159/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_17
# *********** Converting 160/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_55
# *********** Converting 161/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_agency_174
# *********** Converting 162/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_108
# *********** Converting 163/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_83
# *********** Converting 164/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_agency_125
# *********** Converting 165/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_agency_145
# *********** Converting 166/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_141
# *********** Converting 167/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_loan_132
# *********** Converting 168/412 ***********
# Successfully created and saved (16) RGB images in data/input_features/image/phishing/data_agency_191
# *********** Converting 169/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_143
# *********** Converting 170/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_155
# *********** Converting 171/412 ***********
# Successfully created and saved (39) RGB images in data/input_features/image/phishing/data_agency_128
# *********** Converting 172/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_agency_55
# *********** Converting 173/412 ***********
# Successfully created and saved (12) RGB images in data/input_features/image/phishing/data_agency_223
# *********** Converting 174/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_168
# *********** Converting 175/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_114
# *********** Converting 176/412 ***********
# Successfully created and saved (46) RGB images in data/input_features/image/phishing/data_agency_189
# *********** Converting 177/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_161
# *********** Converting 178/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_33
# *********** Converting 179/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_203
# *********** Converting 180/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_171
# *********** Converting 181/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_97
# *********** Converting 182/412 ***********
# Successfully created and saved (7) RGB images in data/input_features/image/phishing/data_loan_110
# *********** Converting 183/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_agency_84
# *********** Converting 184/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_30
# *********** Converting 185/412 ***********
# Successfully created and saved (35) RGB images in data/input_features/image/phishing/data_agency_88
# *********** Converting 186/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_180
# *********** Converting 187/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_126
# *********** Converting 188/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_82
# *********** Converting 189/412 ***********
# Successfully created and saved (11) RGB images in data/input_features/image/phishing/data_agency_204
# *********** Converting 190/412 ***********
# Successfully created and saved (29) RGB images in data/input_features/image/phishing/data_agency_136
# *********** Converting 191/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_agency_57
# *********** Converting 192/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_166
# *********** Converting 193/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_49
# *********** Converting 194/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_loan_19
# *********** Converting 195/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_loan_68
# *********** Converting 196/412 ***********
# Successfully created and saved (10) RGB images in data/input_features/image/phishing/data_loan_179
# *********** Converting 197/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_93
# *********** Converting 198/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_183
# *********** Converting 199/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_agency_37
# *********** Converting 200/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_27
# *********** Converting 201/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_144
# *********** Converting 202/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_85
# *********** Converting 203/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_71
# *********** Converting 204/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_agency_218
# *********** Converting 205/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_103
# *********** Converting 206/412 ***********
# Successfully created and saved (10) RGB images in data/input_features/image/phishing/data_agency_95
# *********** Converting 207/412 ***********
# Successfully created and saved (25) RGB images in data/input_features/image/phishing/data_agency_137
# *********** Converting 208/412 ***********
# Successfully created and saved (10) RGB images in data/input_features/image/phishing/data_agency_124
# *********** Converting 209/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_160
# *********** Converting 210/412 ***********
# Successfully created and saved (7) RGB images in data/input_features/image/phishing/data_loan_181
# *********** Converting 211/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_121
# *********** Converting 212/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_138
# *********** Converting 213/412 ***********
# Successfully created and saved (29) RGB images in data/input_features/image/phishing/data_agency_33
# *********** Converting 214/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_152
# *********** Converting 215/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_63
# *********** Converting 216/412 ***********
# Successfully created and saved (38) RGB images in data/input_features/image/phishing/data_agency_39
# *********** Converting 217/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_97
# *********** Converting 218/412 ***********
# Successfully created and saved (9) RGB images in data/input_features/image/phishing/data_loan_104
# *********** Converting 219/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_12
# *********** Converting 220/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_200
# *********** Converting 221/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_115
# *********** Converting 222/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_113
# *********** Converting 223/412 ***********
# Successfully created and saved (13) RGB images in data/input_features/image/phishing/data_agency_25
# *********** Converting 224/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_4
# *********** Converting 225/412 ***********
# Successfully created and saved (61) RGB images in data/input_features/image/phishing/data_agency_132
# *********** Converting 226/412 ***********
# Successfully created and saved (9) RGB images in data/input_features/image/phishing/data_agency_173
# *********** Converting 227/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_83
# *********** Converting 228/412 ***********
# Successfully created and saved (13) RGB images in data/input_features/image/phishing/data_agency_31
# *********** Converting 229/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_169
# *********** Converting 230/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_loan_16
# *********** Converting 231/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_agency_221
# *********** Converting 232/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_loan_13
# *********** Converting 233/412 ***********
# Successfully created and saved (7) RGB images in data/input_features/image/phishing/data_agency_148
# *********** Converting 234/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_94
# *********** Converting 235/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_92
# *********** Converting 236/412 ***********
# Successfully created and saved (8) RGB images in data/input_features/image/phishing/data_loan_70
# *********** Converting 237/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_40
# *********** Converting 238/412 ***********
# Successfully created and saved (8) RGB images in data/input_features/image/phishing/data_loan_82
# *********** Converting 239/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_72
# *********** Converting 240/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_agency_77
# *********** Converting 241/412 ***********
# Successfully created and saved (12) RGB images in data/input_features/image/phishing/data_agency_109
# *********** Converting 242/412 ***********
# Successfully created and saved (14) RGB images in data/input_features/image/phishing/data_agency_52
# *********** Converting 243/412 ***********
# Successfully created and saved (9) RGB images in data/input_features/image/phishing/data_agency_56
# *********** Converting 244/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_154
# *********** Converting 245/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_38
# *********** Converting 246/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_loan_53
# *********** Converting 247/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_agency_153
# *********** Converting 248/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_46
# *********** Converting 249/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_110
# *********** Converting 250/412 ***********
# Successfully created and saved (16) RGB images in data/input_features/image/phishing/data_agency_96
# *********** Converting 251/412 ***********
# Successfully created and saved (13) RGB images in data/input_features/image/phishing/data_agency_75
# *********** Converting 252/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_111
# *********** Converting 253/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_116
# *********** Converting 254/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_agency_2
# *********** Converting 255/412 ***********
# Successfully created and saved (9) RGB images in data/input_features/image/phishing/data_loan_175
# *********** Converting 256/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_73
# *********** Converting 257/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_loan_138
# *********** Converting 258/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_3
# *********** Converting 259/412 ***********
# Successfully created and saved (7) RGB images in data/input_features/image/phishing/data_loan_143
# *********** Converting 260/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_89
# *********** Converting 261/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_100
# *********** Converting 262/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_42
# *********** Converting 263/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_140
# *********** Converting 264/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_loan_25
# *********** Converting 265/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_71
# *********** Converting 266/412 ***********
# Successfully created and saved (9) RGB images in data/input_features/image/phishing/data_loan_74
# *********** Converting 267/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_80
# *********** Converting 268/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_92
# *********** Converting 269/412 ***********
# Successfully created and saved (14) RGB images in data/input_features/image/phishing/data_agency_192
# *********** Converting 270/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_103
# *********** Converting 271/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_65
# *********** Converting 272/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_182
# *********** Converting 273/412 ***********
# Successfully created and saved (9) RGB images in data/input_features/image/phishing/data_agency_16
# *********** Converting 274/412 ***********
# Successfully created and saved (10) RGB images in data/input_features/image/phishing/data_agency_43
# *********** Converting 275/412 ***********
# Successfully created and saved (25) RGB images in data/input_features/image/phishing/data_agency_133
# *********** Converting 276/412 ***********
# Successfully created and saved (22) RGB images in data/input_features/image/phishing/data_agency_29
# *********** Converting 277/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_167
# *********** Converting 278/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_122
# *********** Converting 279/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_18
# *********** Converting 280/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_142
# *********** Converting 281/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_64
# *********** Converting 282/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_100
# *********** Converting 283/412 ***********
# Successfully created and saved (51) RGB images in data/input_features/image/phishing/data_agency_208
# *********** Converting 284/412 ***********
# Successfully created and saved (19) RGB images in data/input_features/image/phishing/data_agency_67
# *********** Converting 285/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_60
# *********** Converting 286/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_88
# *********** Converting 287/412 ***********
# Successfully created and saved (15) RGB images in data/input_features/image/phishing/data_loan_101
# *********** Converting 288/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_agency_213
# *********** Converting 289/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_137
# *********** Converting 290/412 ***********
# Successfully created and saved (14) RGB images in data/input_features/image/phishing/data_agency_58
# *********** Converting 291/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_127
# *********** Converting 292/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_loan_105
# *********** Converting 293/412 ***********
# Successfully created and saved (8) RGB images in data/input_features/image/phishing/data_agency_154
# *********** Converting 294/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_106
# *********** Converting 295/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_166
# *********** Converting 296/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_124
# *********** Converting 297/412 ***********
# Successfully created and saved (16) RGB images in data/input_features/image/phishing/data_loan_120
# *********** Converting 298/412 ***********
# Successfully created and saved (14) RGB images in data/input_features/image/phishing/data_agency_139
# *********** Converting 299/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_179
# *********** Converting 300/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_agency_63
# *********** Converting 301/412 ***********
# Successfully created and saved (27) RGB images in data/input_features/image/phishing/data_loan_79
# *********** Converting 302/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_167
# *********** Converting 303/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_158
# *********** Converting 304/412 ***********
# Successfully created and saved (7) RGB images in data/input_features/image/phishing/data_agency_10
# *********** Converting 305/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_102
# *********** Converting 306/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_224
# *********** Converting 307/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_98
# *********** Converting 308/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_146
# *********** Converting 309/412 ***********
# Successfully created and saved (8) RGB images in data/input_features/image/phishing/data_agency_159
# *********** Converting 310/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_162
# *********** Converting 311/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_44
# *********** Converting 312/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_170
# *********** Converting 313/412 ***********
# Successfully created and saved (7) RGB images in data/input_features/image/phishing/data_agency_32
# *********** Converting 314/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_loan_174
# *********** Converting 315/412 ***********
# Successfully created and saved (7) RGB images in data/input_features/image/phishing/data_loan_6
# *********** Converting 316/412 ***********
# Successfully created and saved (10) RGB images in data/input_features/image/phishing/data_agency_93
# *********** Converting 317/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_agency_20
# *********** Converting 318/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_118
# *********** Converting 319/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_111
# *********** Converting 320/412 ***********
# Successfully created and saved (44) RGB images in data/input_features/image/phishing/data_agency_209
# *********** Converting 321/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_105
# *********** Converting 322/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_115
# *********** Converting 323/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_117
# *********** Converting 324/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_9
# *********** Converting 325/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_186
# *********** Converting 326/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_59
# *********** Converting 327/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_22
# *********** Converting 328/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_72
# *********** Converting 329/412 ***********
# Successfully created and saved (25) RGB images in data/input_features/image/phishing/data_agency_217
# *********** Converting 330/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_loan_21
# *********** Converting 331/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_152
# *********** Converting 332/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_165
# *********** Converting 333/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_79
# *********** Converting 334/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_148
# *********** Converting 335/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_112
# *********** Converting 336/412 ***********
# Successfully created and saved (8) RGB images in data/input_features/image/phishing/data_agency_54
# *********** Converting 337/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_162
# *********** Converting 338/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_220
# *********** Converting 339/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_225
# *********** Converting 340/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_155
# *********** Converting 341/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_144
# *********** Converting 342/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_210
# *********** Converting 343/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_14
# *********** Converting 344/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_136
# *********** Converting 345/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_90
# *********** Converting 346/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_19
# *********** Converting 347/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_170
# *********** Converting 348/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_198
# *********** Converting 349/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_39
# *********** Converting 350/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_11
# *********** Converting 351/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_agency_4
# *********** Converting 352/412 ***********
# Successfully created and saved (12) RGB images in data/input_features/image/phishing/data_agency_122
# *********** Converting 353/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_201
# *********** Converting 354/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_77
# *********** Converting 355/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_agency_158
# *********** Converting 356/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_62
# *********** Converting 357/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_15
# *********** Converting 358/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_24
# *********** Converting 359/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_226
# *********** Converting 360/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_40
# *********** Converting 361/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_loan_112
# *********** Converting 362/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_27
# *********** Converting 363/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_agency_150
# *********** Converting 364/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_agency_8
# *********** Converting 365/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_31
# *********** Converting 366/412 ***********
# Successfully created and saved (10) RGB images in data/input_features/image/phishing/data_agency_149
# *********** Converting 367/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_agency_12
# *********** Converting 368/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_64
# *********** Converting 369/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_65
# *********** Converting 370/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_151
# *********** Converting 371/412 ***********
# Successfully created and saved (7) RGB images in data/input_features/image/phishing/data_agency_9
# *********** Converting 372/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_agency_36
# *********** Converting 373/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_agency_13
# *********** Converting 374/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_202
# *********** Converting 375/412 ***********
# Successfully created and saved (5) RGB images in data/input_features/image/phishing/data_agency_99
# *********** Converting 376/412 ***********
# Successfully created and saved (13) RGB images in data/input_features/image/phishing/data_loan_78
# *********** Converting 377/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_175
# *********** Converting 378/412 ***********
# Successfully created and saved (29) RGB images in data/input_features/image/phishing/data_agency_130
# *********** Converting 379/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_90
# *********** Converting 380/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_14
# *********** Converting 381/412 ***********
# Successfully created and saved (45) RGB images in data/input_features/image/phishing/data_agency_216
# *********** Converting 382/412 ***********
# Successfully created and saved (6) RGB images in data/input_features/image/phishing/data_loan_67
# *********** Converting 383/412 ***********
# Successfully created and saved (9) RGB images in data/input_features/image/phishing/data_agency_69
# *********** Converting 384/412 ***********
# Successfully created and saved (39) RGB images in data/input_features/image/phishing/data_agency_215
# *********** Converting 385/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_loan_2
# *********** Converting 386/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_127
# *********** Converting 387/412 ***********
# Successfully created and saved (11) RGB images in data/input_features/image/phishing/data_agency_1
# *********** Converting 388/412 ***********
# Successfully created and saved (26) RGB images in data/input_features/image/phishing/data_agency_129
# *********** Converting 389/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_113
# *********** Converting 390/412 ***********
# Successfully created and saved (18) RGB images in data/input_features/image/phishing/data_loan_69
# *********** Converting 391/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_70
# *********** Converting 392/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_107
# *********** Converting 393/412 ***********
# Successfully created and saved (39) RGB images in data/input_features/image/phishing/data_agency_195
# *********** Converting 394/412 ***********
# Successfully created and saved (7) RGB images in data/input_features/image/phishing/data_loan_133
# *********** Converting 395/412 ***********
# Successfully created and saved (10) RGB images in data/input_features/image/phishing/data_agency_140
# *********** Converting 396/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_11
# *********** Converting 397/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_agency_120
# *********** Converting 398/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_29
# *********** Converting 399/412 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/phishing/data_agency_146
# *********** Converting 400/412 ***********
# Successfully created and saved (7) RGB images in data/input_features/image/phishing/data_agency_102
# *********** Converting 401/412 ***********
# Successfully created and saved (9) RGB images in data/input_features/image/phishing/data_agency_30
# *********** Converting 402/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_109
# *********** Converting 403/412 ***********
# Successfully created and saved (8) RGB images in data/input_features/image/phishing/data_agency_6
# *********** Converting 404/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_177
# *********** Converting 405/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_loan_96
# *********** Converting 406/412 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/phishing/data_loan_172
# *********** Converting 407/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_49
# *********** Converting 408/412 ***********
# Successfully created and saved (1) RGB images in data/input_features/image/phishing/data_agency_178
# *********** Converting 409/412 ***********
# Successfully created and saved (23) RGB images in data/input_features/image/phishing/data_agency_187
# *********** Converting 410/412 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/phishing/data_loan_147
# *********** Converting 411/412 ***********
# Successfully created and saved (12) RGB images in data/input_features/image/phishing/data_agency_117
# *********** Converting 412/412 ***********
# Successfully created and saved (7) RGB images in data/input_features/image/phishing/data_loan_106

# %%
parent_dir_audio = "data/splitted/nonphishing"
parent_dir_image = "data/input_features/image/nonphishing"
audio_dir_list = [os.path.join(parent_dir_audio, f) for f in os.listdir(parent_dir_audio) if not f.startswith('.')]
image_dir_list = [os.path.join(parent_dir_image, f) for f in os.listdir(parent_dir_audio) if not f.startswith('.')]

# %%
for i in range(len(audio_dir_list)):
    audio_dir = audio_dir_list[i]
    image_dir = image_dir_list[i]
    print(f"*********** Converting {i+1}/{len(audio_dir_list)} ***********")
    if audio_dir.rsplit('/', 1)[-1] == image_dir.rsplit('/', 1)[-1]:
        melspec_to_rgb_image(audio_dir, image_dir)
    else:
        print(f"Source file (audio) is different from destination file (image)")
# Out:
# *********** Converting 1/500 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/nonphishing/data_transaction_hist_97
# *********** Converting 2/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_53
# *********** Converting 3/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_transaction_hist_2
# *********** Converting 4/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_124
# *********** Converting 5/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_144
# *********** Converting 6/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_loan_service_98
# *********** Converting 7/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_141
# *********** Converting 8/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_loan_service_90
# *********** Converting 9/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_55
# *********** Converting 10/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_transaction_hist_23
# *********** Converting 11/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_transaction_hist_26
# *********** Converting 12/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_130
# *********** Converting 13/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_157
# *********** Converting 14/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_transaction_hist_114
# *********** Converting 15/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_loan_service_52
# *********** Converting 16/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_45
# *********** Converting 17/500 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/nonphishing/data_loan_service_89
# *********** Converting 18/500 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/nonphishing/data_transaction_hist_138
# *********** Converting 19/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_transaction_hist_79
# *********** Converting 20/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_transaction_hist_39
# *********** Converting 21/500 ***********
# Successfully created and saved (4) RGB images in data/input_features/image/nonphishing/data_loan_service_86
# *********** Converting 22/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_loan_service_49
# *********** Converting 23/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_134
# *********** Converting 24/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_transaction_hist_65
# *********** Converting 25/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_115
# *********** Converting 26/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_loan_service_117
# *********** Converting 27/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_84
# *********** Converting 28/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_72
# *********** Converting 29/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_transaction_hist_88
# *********** Converting 30/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_18
# *********** Converting 31/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_152
# *********** Converting 32/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_43
# *********** Converting 33/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_85
# *********** Converting 34/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_loan_service_33
# *********** Converting 35/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_transaction_hist_75
# *********** Converting 36/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_57
# *********** Converting 37/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_102
# *********** Converting 38/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_28
# *********** Converting 39/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_160
# *********** Converting 40/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_transaction_hist_147
# *********** Converting 41/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_34
# *********** Converting 42/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_142
# *********** Converting 43/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_transaction_hist_90
# *********** Converting 44/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_63
# *********** Converting 45/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_95
# *********** Converting 46/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_transaction_hist_32
# *********** Converting 47/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_transaction_hist_161
# *********** Converting 48/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_155
# *********** Converting 49/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_117
# *********** Converting 50/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_26
# *********** Converting 51/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_transaction_hist_29
# *********** Converting 52/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_3
# *********** Converting 53/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_79
# *********** Converting 54/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_transaction_hist_153
# *********** Converting 55/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_22
# *********** Converting 56/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_transaction_hist_68
# *********** Converting 57/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_loan_service_41
# *********** Converting 58/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_86
# *********** Converting 59/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_transaction_hist_101
# *********** Converting 60/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_94
# *********** Converting 61/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_127
# *********** Converting 62/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_107
# *********** Converting 63/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_loan_service_102
# *********** Converting 64/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_99
# *********** Converting 65/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_58
# *********** Converting 66/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_loan_service_29
# *********** Converting 67/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_transaction_hist_134
# *********** Converting 68/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_19
# *********** Converting 69/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_149
# *********** Converting 70/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_transaction_hist_132
# *********** Converting 71/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_138
# *********** Converting 72/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_23
# *********** Converting 73/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_transaction_hist_1
# *********** Converting 74/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_154
# *********** Converting 75/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_transaction_hist_22
# *********** Converting 76/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_153
# *********** Converting 77/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_subscription_cancellation_36
# *********** Converting 78/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_transaction_hist_43
# *********** Converting 79/500 ***********
# Successfully created and saved (2) RGB images in data/input_features/image/nonphishing/data_loan_service_7
# *********** Converting 80/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_loan_service_15
# *********** Converting 81/500 ***********
# Successfully created and saved (3) RGB images in data/input_features/image/nonphishing/data_transaction_hist